# 11         NaN           NaN               NaN
# 12         NaN           NaN               NaN
# 13         NaN           NaN               NaN
# 14         NaN           NaN               NaN
# 15         NaN           NaN               NaN
# 16          AC           6.0  DEPUTADO FEDERAL
# 17         NaN           NaN               NaN
# 18         NaN           NaN               NaN
# ...

# %%
federais.dropna()
# Out:
#       SIGLA_UF  CODIGO_CARGO   DESCRICAO_CARGO  \
# 39          AC           6.0  DEPUTADO FEDERAL
# 47          AC           6.0  DEPUTADO FEDERAL
# 48          AC           6.0  DEPUTADO FEDERAL
# 85          AC           6.0  DEPUTADO FEDERAL
# 101         AC           6.0  DEPUTADO FEDERAL
# 118         AC           6.0  DEPUTADO FEDERAL
# 122         AC           6.0  DEPUTADO FEDERAL
# 123         AC           6.0  DEPUTADO FEDERAL
# 124         AC           6.0  DEPUTADO FEDERAL
# 126         AC           6.0  DEPUTADO FEDERAL
# 137         AC           6.0  DEPUTADO FEDERAL
# 208         AC           6.0  DEPUTADO FEDERAL
# 209         AC           6.0  DEPUTADO FEDERAL
# 221         AC           6.0  DEPUTADO FEDERAL
# 239         AC           6.0  DEPUTADO FEDERAL
# 275         AC           6.0  DEPUTADO FEDERAL
# 278         AC           6.0  DEPUTADO FEDERAL
# 285         AC           6.0  DEPUTADO FEDERAL
# 289         AC           6.0  DEPUTADO FEDERAL
# ...

# %%
eleitos = df.where(df['DESC_SIT_TOT_TURNO'] == 'ELEITO POR QP').dropna()

# %%
print(eleitos)
print(type(eleitos))
# Out:
#       SIGLA_UF  CODIGO_CARGO    DESCRICAO_CARGO  \
# 13          AC           7.0  DEPUTADO ESTADUAL
# 81          AC           7.0  DEPUTADO ESTADUAL
# 101         AC           6.0   DEPUTADO FEDERAL
# 188         AC           7.0  DEPUTADO ESTADUAL
# 199         AC           7.0  DEPUTADO ESTADUAL
# 262         AC           7.0  DEPUTADO ESTADUAL
# 285         AC           6.0   DEPUTADO FEDERAL
# 302         AC           7.0  DEPUTADO ESTADUAL
# 334         AC           7.0  DEPUTADO ESTADUAL
# 348         AC           6.0   DEPUTADO FEDERAL
# 356         AC           7.0  DEPUTADO ESTADUAL
# 375         AC           6.0   DEPUTADO FEDERAL
# 386         AC           7.0  DEPUTADO ESTADUAL
# 396         AC           7.0  DEPUTADO ESTADUAL
# 414         AC           7.0  DEPUTADO ESTADUAL
# 456         AC           6.0   DEPUTADO FEDERAL
# 470         AC           6.0   DEPUTADO FEDERAL
# 529         AC           7.0  DEPUTADO ESTADUAL
# ...

# %%
eleitos = ((df.DESC_SIT_TOT_TURNO == 'ELEITO POR QP') | (df.DESC_SIT_TOT_TURNO == 'SUPLENTE'))

# %%
#print(eleitos)
df.loc[df['DESC_SIT_TOT_TURNO'] == 'ELEITO POR QP']
# Out:
#       SIGLA_UF  CODIGO_CARGO    DESCRICAO_CARGO  \
#
# Out:
#       SIGLA_UF  CODIGO_CARGO    DESCRICAO_CARGO  \
# 60          AC             7  DEPUTADO ESTADUAL
# 166         AC             7  DEPUTADO ESTADUAL
# 170         AC             7  DEPUTADO ESTADUAL
# 344         AC             7  DEPUTADO ESTADUAL
# 369         AC             7  DEPUTADO ESTADUAL
# 395         AC             6   DEPUTADO FEDERAL
# 497         AC             7  DEPUTADO ESTADUAL
# 548         AC             7  DEPUTADO ESTADUAL
# 585         AL             7  DEPUTADO ESTADUAL
# 724         AL             7  DEPUTADO ESTADUAL
# 755         AL             7  DEPUTADO ESTADUAL
# 780         AL             6   DEPUTADO FEDERAL
# 898         AL             7  DEPUTADO ESTADUAL
# 985         AM             7  DEPUTADO ESTADUAL
# 1172        AM             7  DEPUTADO ESTADUAL
# 1185        AM             7  DEPUTADO ESTADUAL
# 1219        AM             7  DEPUTADO ESTADUAL
# 1308        AM             7  DEPUTADO ESTADUAL
# ...

# %%
df[(df['DESC_SIT_TOT_TURNO'] == 'ELEITO POR QP') | (df['DESC_SIT_TOT_TURNO'] == 'ELEITO POR MEDIA')]
# Out:
#       SIGLA_UF  CODIGO_CARGO    DESCRICAO_CARGO  \
# 13          AC             7  DEPUTADO ESTADUAL
# 23          AC             7  DEPUTADO ESTADUAL
# 60          AC             7  DEPUTADO ESTADUAL
# 81          AC             7  DEPUTADO ESTADUAL
# 101         AC             6   DEPUTADO FEDERAL
# 166         AC             7  DEPUTADO ESTADUAL
# 170         AC             7  DEPUTADO ESTADUAL
# 188         AC             7  DEPUTADO ESTADUAL
# 199         AC             7  DEPUTADO ESTADUAL
# 250         AC             7  DEPUTADO ESTADUAL
# 262         AC             7  DEPUTADO ESTADUAL
# 280         AC             7  DEPUTADO ESTADUAL
# 285         AC             6   DEPUTADO FEDERAL
# 302         AC             7  DEPUTADO ESTADUAL
# 334         AC             7  DEPUTADO ESTADUAL
# 344         AC             7  DEPUTADO ESTADUAL
# 348         AC             6   DEPUTADO FEDERAL
# 356         AC             7  DEPUTADO ESTADUAL
# ...

# %%
cand_nao_eleitos = df[df['DESC_SIT_TOT_TURNO'] == 'NAO ELEITO']

# %%
cand_eleitos = df[(df['DESC_SIT_TOT_TURNO'] == 'ELEITO POR QP') | (df['DESC_SIT_TOT_TURNO'] == 'ELEITO POR MEDIA')]

# %% [markdown]
# =====================IDADE_DATA_ELEICAO==========================

# %%
print("media idade nao eleitos: " + str(cand_nao_eleitos['IDADE_DATA_ELEICAO'].mean()))
print("mediana idade nao eleitos: " + str(cand_nao_eleitos['IDADE_DATA_ELEICAO'].median()))
print("moda idade nao eleitos: " + str(cand_nao_eleitos['IDADE_DATA_ELEICAO'].mode()))
print("variancia idade nao eleitos: " + str(cand_nao_eleitos['IDADE_DATA_ELEICAO'].var()))
print("desvio padrao idade nao eleitos: " + str(cand_nao_eleitos['IDADE_DATA_ELEICAO'].std()))
# Out:
# media idade nao eleitos: 45.82093581283743
# mediana idade nao eleitos: 46.0
# moda idade nao eleitos: 0    45
# dtype: int64
# variancia idade nao eleitos: 132.87671727580832
# desvio padrao idade nao eleitos: 11.527216371518682

# %%
print("media idade eleitos: " + str(cand_eleitos['IDADE_DATA_ELEICAO'].mean()))
print("mediana idade eleitos: " + str(cand_eleitos['IDADE_DATA_ELEICAO'].median()))
print("moda idade eleitos: " + str(cand_eleitos['IDADE_DATA_ELEICAO'].mode()))
print("variancia idade eleitos: " + str(cand_eleitos['IDADE_DATA_ELEICAO'].var()))
print("desvio padrao idade eleitos: " + str(cand_eleitos['IDADE_DATA_ELEICAO'].std()))
# Out:
# media idade eleitos: 49.10496183206107
# mediana idade eleitos: 50.0
# moda idade eleitos: 0    51
# dtype: int64
# variancia idade eleitos: 131.3772637159201
# desvio padrao idade eleitos: 11.461992135572249

# %%
cand_nao_eleitos['IDADE_DATA_ELEICAO'].hist(bins=100)

# %%
cand_eleitos['IDADE_DATA_ELEICAO'].hist(bins=100)

# %% [markdown]
# ==================DESPESA_MAX_CAMPANHA=====================

# %%
print("media despesa nao eleitos: " + str(cand_nao_eleitos['DESPESA_MAX_CAMPANHA'].mean()))
print("mediana despesa nao eleitos: " + str(cand_nao_eleitos['DESPESA_MAX_CAMPANHA'].median()))
print("moda despesa nao eleitos: " + str(cand_nao_eleitos['DESPESA_MAX_CAMPANHA'].mode()))
print("variancia despesa nao eleitos: " + str(cand_nao_eleitos['DESPESA_MAX_CAMPANHA'].var()))
print("desvio padrao despesa nao eleitos: " + str(cand_nao_eleitos['DESPESA_MAX_CAMPANHA'].std()))
# Out:
# media despesa nao eleitos: 1928973.6052789441
# mediana despesa nao eleitos: 1500000.0
# moda despesa nao eleitos: 0    1000000
# dtype: int64
# variancia despesa nao eleitos: 4272032053158.573
# desvio padrao despesa nao eleitos: 2066889.4632172696

# %%
print("media despesa eleitos: " + str(cand_eleitos['DESPESA_MAX_CAMPANHA'].mean()))
print("mediana despesa eleitos: " + str(cand_eleitos['DESPESA_MAX_CAMPANHA'].median()))
print("moda despesa eleitos: " + str(cand_eleitos['DESPESA_MAX_CAMPANHA'].mode()))
print("variancia despesa eleitos: " + str(cand_eleitos['DESPESA_MAX_CAMPANHA'].var()))
print("desvio padrao despesa eleitos: " + str(cand_eleitos['DESPESA_MAX_CAMPANHA'].std()))
# Out:
# media despesa eleitos: 3343464.3765903306
# mediana despesa eleitos: 3000000.0
# moda despesa eleitos: 0    2000000
# dtype: int64
# variancia despesa eleitos: 17405908816680.383
# desvio padrao despesa eleitos: 4172038.9279919695

# %%
cand_nao_eleitos['DESPESA_MAX_CAMPANHA'].plot(kind='pie')
